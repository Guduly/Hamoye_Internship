# %%
import matplotlib.pyplot as plt
from sklearn import linear_model
import pandas as pd
import numpy as np
import math

# %%
df = pd.read_csv(r"C:\Users\preet\Downloads\energydata_complete.csv", encoding='ISO-8859-1')
df
# Out:
#                       date  Appliances  lights         T1       RH_1  \
# 0      2016-01-11 17:00:00          60      30  19.890000  47.596667
# 1      2016-01-11 17:10:00          60      30  19.890000  46.693333
# 2      2016-01-11 17:20:00          50      30  19.890000  46.300000
# 3      2016-01-11 17:30:00          50      40  19.890000  46.066667
# 4      2016-01-11 17:40:00          60      40  19.890000  46.333333
# ...                    ...         ...     ...        ...        ...
# 19730  2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731  2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732  2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733  2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734  2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3         T4  ...         T9  \
# ...

# %%
X = df[['T2']]
Y = df.T6

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size=.2)

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(X, Y)
# Out:
# LinearRegression()

# %%
predicted_Val = reg.predict(x_test)
predicted_Val
# Out:
# array([ 7.15170508,  4.4593808 , -0.12424565, ..., 13.2928745 ,
#         4.25912528, 13.15937082])

# %%
## problem 17
from sklearn.metrics import mean_squared_error
error = mean_squared_error(y_test, predicted_Val)
print(round(math.sqrt(error), 3))
# Out:
# 3.623

# %%
## problem 19
multi = df.drop(['date', 'lights'], axis='columns')
multi
# Out:
#        Appliances         T1       RH_1         T2       RH_2         T3  \
# 0              60  19.890000  47.596667  19.200000  44.790000  19.790000
# 1              60  19.890000  46.693333  19.200000  44.722500  19.790000
# 2              50  19.890000  46.300000  19.200000  44.626667  19.790000
# 3              50  19.890000  46.066667  19.200000  44.590000  19.790000
# 4              60  19.890000  46.333333  19.200000  44.530000  19.790000
# ...           ...        ...        ...        ...        ...        ...
# 19730         100  25.566667  46.560000  25.890000  42.025714  27.200000
# 19731          90  25.500000  46.500000  25.754000  42.080000  27.133333
# 19732         270  25.500000  46.596667  25.628571  42.768571  27.050000
# 19733         420  25.500000  46.990000  25.414000  43.036000  26.890000
# 19734         430  25.500000  46.600000  25.264286  42.971429  26.823333
#
#             RH_3         T4       RH_4         T5  ...         T9     RH_9  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scale = MinMaxScaler()

normal_df = pd.DataFrame(scale.fit_transform(multi), columns=multi.columns)


Y2 = normal_df.Appliances
X2 = normal_df[['T2']]

# %%
x1_train, x1_test, y1_train, y1_test = train_test_split(X2, Y2, test_size=.3, random_state=42)
reg.fit(x1_train,y1_train)
# Out:
# LinearRegression()

# %%
predicted = reg.predict(x1_test)
from sklearn.metrics import mean_absolute_error
n_error = mean_absolute_error(y1_test, predicted)
print(n_error)

## 20-25 were Guesses due to getting the wrong output for problem 19
# Out:
# 0.05568196458760597
